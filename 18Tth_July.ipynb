# %% [markdown]
# <a href="https://colab.research.google.com/github/madhavoza18-max/Python-warmup/blob/main/18Tth_July.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## my first session of python.

# %%
x=100

# %%
x
# Out:
# 100

# %%
name='madhav'

# %%
name
# Out:
# 'madhav'

# %%
name='asha'

# %%
name
# Out:
# 'asha'

# %%
x=100
y=21
z=x*y
z
# Out:
# 2100

# %%
print(name)
# Out:
# asha

# %%
x=100                         #assigning value to x
x
#caling value of x
# Out:
# 100

# %%
print("hello","world")
# Out:
# hello world

# %%
print("hello")
# Out:
# hello

# %%
x=28

# %%
print(x)
# Out:
# 28

# %%
print("my age is",x)
# Out:
# my age is 28

# %%
print(7*9)
# Out:
# 63

# %%
print("Name: \tMadhav")      #\t is spacing
# Out:
# Name: 	Madhav

# %%
name="madhav"
age=28
height=5.7
is_student= True

# %%
print("My Name is :",name)
print("age is:",age,"years")
print("height:",height)
print("is student?",is_student)
# Out:
# My Name is : madhav
# age is: 28 years
# height: 5.7
# is student? True

# %%
name=input("what is your name?")        #see how to take input from user
print("Hello",name,"wlecome to python.")
# Out:
# what is your name?JOKO
# Hello JOKO wlecome to python.

# %%
name="madhav"
subject="maths"
yob=1998
print("My name is",name,"and my favorite subject is",subject,"my year of birth is",yob,"and I like python very much")
# Out:
# My name is madhav and my favorite subject is maths my year of birth is 1998 and I like python very much

# %% [markdown]
# ##TYPES OF DATA IN PYTHON

# %%
age_text="29"      ##note that here an integer is written within the double coma therefore type is string.
age_text
# Out:
# '29'

# %%
type(age_text)
# Out:
# str

# %%
age_number=int(age_text)    ##string to integer convert

# %%
age_number
# Out:
# 29

# %%
#converting integer into string
score=108
message="your score is:"+str(score)        # +str() is to string
print(message)
print(type(message))
# Out:
# your score is:108
# <class 'str'>

# %%
print(type(0))
# Out:
# <class 'int'>

# %%
print(type("90"))
# Out:
# <class 'str'>

# %%
number_is=90
print(type(number_is))
# Out:
# <class 'int'>

# %%
conversion="now the type of the number :"+str(number_is)
print(conversion)
print(type(conversion))
# Out:
# now the type of the number :90
# <class 'str'>

# %% [markdown]
# ##floor and ciel command by importing math

# %%
import math

# %%
a=32.4
print(math.floor(a))
print(math.ceil(a))
# Out:
# 32
# 33

# %% [markdown]
# ##python has 4 types of division in maths

# %%
from binascii import b2a_base64
import math
a=17
b=5

remainder=a%b
print(float(a%b))
print(math.ceil(a%b))
print(remainder)
print(a**b)
# Out:
# 2.0
# 2
# 2
# 1419857

# %%
song_year=2025
print(2020 <= song_year <=2026)
# Out:
# True

# %%
print((7>=6) or (2>9))
# Out:
# True

# %%
print(str("hello"))
# Out:
# hello

# %% [markdown]
# ##MY FIRST PROGRAMME

# %%
Tea_cost=10
coffee_cost=25

print("Hello sir welcome to the cafe, what would you like to order?")
order_tea=input("how many tea:")
order_coffee=input("how many coffee:")
print("ok sir, your order summary is",order_tea,"tea and",order_coffee,"coffee and 5% GST.")
order_bill=int(order_tea)*Tea_cost+int(order_coffee)*coffee_cost
total_amount_to_pay=order_bill+order_bill*0.05
print(f"your total amount to pay is:",{ round(total_amount_to_pay,2)  })   ###round is for roundingoff the value to uptp 2 decimal
# Out:
# Hello sir welcome to the cafe, what would you like to order?
# how many tea:3
# how many coffee:2
# ok sir, your order summary is 3 tea and 2 coffee and 5% GST.
# your total amount to pay is: {84.0}
