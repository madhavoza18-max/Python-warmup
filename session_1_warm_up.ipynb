# %% [markdown]
# <a href="https://colab.research.google.com/github/madhavoza18-max/Python-warmup/blob/main/session_1_warm_up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from colab")
# Out:
# Hello from colab

# %% [markdown]
# #My first note book

# %%
print(type(11))
print(type(21.213))
print(type("Hello"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(type(1))
print(type(1.2))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(1==1.0)
# Out:
# True

# %%
print(type(2.0))
print(type("33"))
print(type(22))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
import math
value=4.7
print(math.floor(value))
print(math.ceil(value))
# Out:
# 4
# 5

# %%
import matplotlib.pyplot as plt
a=15
b=3
remainder=a%b
print(float(a%b))
print(int(a%b))
print(math.ceil(a%b))
print(math.floor(a%b))
print(remainder)
print(a**b)
# Out:
# 0.0
# 0
# 0
# 0
# 0
# 3375

# %%
print(30+2*60)
# Out:
# 150

# %%
print(20+950*2)
# Out:
# 1920

# %%
song_1=42
song_2=43
song_3=57

total_minutes=song_1+song_2+song_3
total_hours=total_minutes/60
print(total_hours)
# Out:
# 2.3666666666666667

# %%
score=90
print(score==90)
# Out:
# True

# %%
print(score!=100)
# Out:
# True

# %%
print(score==100)
# Out:
# False

# %%
album_year=1982
print(1980<= album_year <=1989)
# Out:
# True

# %%
print(5>3 or 2>9)
# Out:
# True

# %%
print(5+ 5 or 10+3)
# Out:
# 10

# %%
print(int(20))
# Out:
# 20

# %% [markdown]
# ##MY first programme

# %%
tea_price=10
coffee_price=25

tea_quantity=3
coffee_quantity=2

tea_total=tea_price * tea_quantity
coffee_total=coffee_price * coffee_quantity

total_bill=tea_total + coffee_total

gst_amount=total_bill*0.05

final_bill=total_bill + gst_amount

print(f"final_bill is : ,{round(final_bill,2)}rupees")
# Out:
# final_bill is : ,84.0rupees

# %%
tea_price =10
coffee_price = 25

tea_quantity = 3
coffee_quantity = 2

tea_total = tea_price * tea_quantity
coffee_total = coffee_price * coffee_quantity

total_amount = tea_total + coffee_total

gst_amount = total_amount * 0.05

final_amount = total_amount + gst_amount

print(f"Final amount: ,{round(final_amount, 2) } rupees")
# Out:
# Final amount: ,84.0 rupees
